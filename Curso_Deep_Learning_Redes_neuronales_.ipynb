# %% [markdown]
# <a href="https://colab.research.google.com/github/carlo-coding/curso_deep_learning/blob/main/Curso_Deep_Learning_Redes_neuronales_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import make_circles
import numpy as np
import matplotlib.pyplot as plt


x, y = make_circles(n_samples=600, noise=0.08, factor=0.5)


y = np.reshape(y, (-1, 1))

plt.scatter(x[y[:, 0] == 1, 0], x[y[:, 0] == 1, 1], color="red")
plt.scatter(x[y[:, 0] == 0, 0], x[y[:, 0] == 0, 1], color="blue")
plt.axis("equal")
plt.grid()
plt.show()

print(x.shape, y.shape)
# Out:
# (600, 2) (600, 1)

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense

model = Sequential()

model.add(Dense(16, activation="relu", input_shape=(2,)))
model.add(Dense(16, activation="relu"))
model.add(Dense(1, activation="sigmoid"))

model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_9 (Dense)             (None, 16)                48
#
#  dense_10 (Dense)            (None, 16)                272
#
#  dense_11 (Dense)            (None, 1)                 17
#
# ...
# Total params: 337
# Trainable params: 337
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(
    loss="mse",
    optimizer="sgd",
    metrics=["acc"]
)

# %%
model.fit(x, y, epochs=200)
# Out:
# Epoch 1/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2538 - acc: 0.5017
# Epoch 2/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2534 - acc: 0.4917
# Epoch 3/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2530 - acc: 0.4933
# Epoch 4/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2527 - acc: 0.4950
# Epoch 5/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2523 - acc: 0.4883
# Epoch 6/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2520 - acc: 0.4900
# Epoch 7/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2517 - acc: 0.4967
# Epoch 8/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2514 - acc: 0.4967
# Epoch 9/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2510 - acc: 0.4917
# Epoch 10/200
# 19/19 [==============================] - 0s 2ms/step - loss: 0.2507 - acc: 0.4967
# Epoch 11/200
# ...

# %%
res = 50
_x0 = np.linspace(-1.5, 1.5, res)
_x1 = np.linspace(-1.5, 1.5, res)
_Y = np.zeros((res, res))
for i0, x0 in enumerate(_x0):
  for i1, x1 in enumerate(_x1):
    _Y[i0, i1] = model(np.array([[x0, x1]]), training=False)[0][0]
plt.pcolormesh(_x0, _x1, _Y.T, cmap="coolwarm")
plt.scatter(x[y[:,0] == 0, 0], x[y[:,0] == 0, 1], c="skyblue")
plt.scatter(x[y[:,0] == 1, 0], x[y[:,0] == 1, 1], c="salmon")
plt.axis("equal")
plt.grid()
plt.show()

plt.show()
